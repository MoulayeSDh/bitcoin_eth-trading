# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot  as plt 
#from sklearn.preprocessing import 
import seaborn as sns
# %matplotlib inline

# %%
btc=pd.read_csv("BTC-USD.csv",index_col='Date',parse_dates=True)
btc.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-03-01  254.283005  300.044006  236.514999  244.223999  244.223999
# 2015-04-01  244.223007  261.798004  214.873993  236.145004  236.145004
# 2015-05-01  235.938995  247.804001  228.572998  230.190002  230.190002
# 2015-06-01  230.233002  267.867004  221.296005  263.071991  263.071991
# 2015-07-01  263.345001  314.394012  253.505005  284.649994  284.649994
#
#                Volume
# Date
# 2015-03-01  959098300
# 2015-04-01  672338700
# 2015-05-01  568122600
# 2015-06-01  629780200
# 2015-07-01  999892200

# %%
btc_data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
plt.figure(figsize=(12,8))
plt.plot(btc.Close,'r--',lw=1)
plt.plot(btc.Open,'b--',lw=1)

plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot (btc.loc['2020':'2023', 'Close'],'r--');
plt.plot (btc.loc['2020':'2023', 'Open'],'b--');
plt.title("BTC USD EVOLUTION ENTRE 2020 ET 2023")
# Out:
# Text(0.5, 1.0, 'BTC USD EVOLUTION ENTRE 2020 ET 2023')

# %%
btc.loc['2019', 'Close'].resample('T').plot()
